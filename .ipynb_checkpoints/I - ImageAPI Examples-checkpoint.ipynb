# %% [markdown]
# # Image API
#
# This notebook provides an overview of PHL-Microsat's Image API endpoint: A catalog of Diwata-1 images.
#
# The ImageAPI has a couple of endpoints available:
# * [/scenes](#scenes)
# * [/scenes/histogram](#histogram)
# * [/scenes/geohash](#geohash)

# %%
import requests
API_URL = 'https://api.orange.phl-microsat.xyz'

# %% [markdown]
# ## GET /scenes <a class="anchor" id="scenes"></a>
#
# This endpoint serves a list of satellite images.

# %% [markdown]
# ### Fetch Data
# Let's make a request using the default parameters

# %%
r = requests.get(API_URL + '/scenes')
r.json()
# Out:
# {'data': [{'scene_id': 'D1_SMI_2018-06-22T053111055_V550',
#    'scene_center': {'type': 'Point',
#     'coordinates': [122.43041191598462, 13.499050232561672]},
#    'scene_footprint': {'type': 'Polygon',
#     'coordinates': [[[122.62270772244743, 13.438726191427726],
#       [122.42199776143877, 13.303514648530331],
#       [122.23811610952181, 13.559374273695617],
#       [122.43882607053047, 13.694585816593012],
#       [122.62270772244743, 13.438726191427726]]]},
#    'satellite_name': 'diwata-1',
#    'payload': 'smi',
#    'cloudcover': None,
#    'capture_time': '2018-06-22T05:31:11.055041',
#    'wavelength': 550.0,
#    'published_time': None,
#    'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053111055_V550/D1_SMI_2018-06-22T053111055_V550.zip',
#     'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053111055_V550/D1_SMI_2018-06-22T053111055_V550-thumb.png'},
#    'image_quality': None,
#    'bands': {'L1A': 'D1_SMI_2018-06-22T053111055_V550_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053111055_V550_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053111055_V550_L1C.tif'},
#    'day_or_night': '',
#    'sun_elevation': 64.52449656078697,
#    'sun_azimuth': 296.56580289395646,
#    'products': {'L1A': 'D1_SMI_2018-06-22T053111055_V550_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053111055_V550_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053111055_V550_L1C.tif'},
#    'satellite_color': None,
#    'payload_color': None,
#    'mission_id': None,
#    'mission_name': None,
#    'mission_start_time': None},
#   {'scene_id': 'D1_SMI_2018-06-22T053111005_V490',
#    'scene_center': {'type': 'Point',
#     'coordinates': [122.41037919898515, 13.524257425972182]},
#    'scene_footprint': {'type': 'Polygon',
#     'coordinates': [[[122.60181321555628, 13.463561180795324],
#       [122.4026086729601, 13.328684017512556],
#       [122.21894518241409, 13.584953671149043],
#       [122.41814972501025, 13.71983083443181],
#       [122.60181321555628, 13.463561180795324]]]},
#    'satellite_name': 'diwata-1',
#    'payload': 'smi',
#    'cloudcover': None,
#    'capture_time': '2018-06-22T05:31:11.005041',
#    'wavelength': 490.0,
#    'published_time': None,
#    'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053111005_V490/D1_SMI_2018-06-22T053111005_V490.zip',
#     'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053111005_V490/D1_SMI_2018-06-22T053111005_V490-thumb.png'},
#    'image_quality': None,
#    'bands': {'L1A': 'D1_SMI_2018-06-22T053111005_V490_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053111005_V490_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053111005_V490_L1C.tif'},
#    'day_or_night': '',
#    'sun_elevation': 64.55355218551621,
#    'sun_azimuth': 296.53258085383357,
#    'products': {'L1A': 'D1_SMI_2018-06-22T053111005_V490_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053111005_V490_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053111005_V490_L1C.tif'},
#    'satellite_color': None,
#    'payload_color': None,
#    'mission_id': None,
#    'mission_name': None,
#    'mission_start_time': None},
#   {'scene_id': 'D1_SMI_2018-06-22T053110055_V530',
#    'scene_center': {'type': 'Point',
#     'coordinates': [122.39014773697839, 13.549283385236455]},
#    'scene_footprint': {'type': 'Polygon',
#     'coordinates': [[[122.58171960927119, 13.48891446156232],
#       [122.38243473264716, 13.353239535978396],
#       [122.19857586468555, 13.609652308910583],
#       [122.39786074130959, 13.745327234494505],
#       [122.58171960927119, 13.48891446156232]]]},
#    'satellite_name': 'diwata-1',
#    'payload': 'smi',
#    'cloudcover': None,
#    'capture_time': '2018-06-22T05:31:10.055041',
#    'wavelength': 530.0,
#    'published_time': None,
#    'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053110055_V530/D1_SMI_2018-06-22T053110055_V530.zip',
#     'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053110055_V530/D1_SMI_2018-06-22T053110055_V530-thumb.png'},
#    'image_quality': None,
#    'bands': {'L1A': 'D1_SMI_2018-06-22T053110055_V530_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053110055_V530_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053110055_V530_L1C.tif'},
#    'day_or_night': '',
#    'sun_elevation': 64.58577701802034,
#    'sun_azimuth': 296.5016810780284,
#    'products': {'L1A': 'D1_SMI_2018-06-22T053110055_V530_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053110055_V530_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053110055_V530_L1C.tif'},
#    'satellite_color': None,
#    'payload_color': None,
#    'mission_id': None,
#    'mission_name': None,
#    'mission_start_time': None},
#   {'scene_id': 'D1_SMI_2018-06-22T053110005_V610',
#    'scene_center': {'type': 'Point',
#     'coordinates': [122.36996222349399, 13.574456910870994]},
#    'scene_footprint': {'type': 'Polygon',
#     'coordinates': [[[122.56144950485401, 13.514324187500495],
#       [122.36229868182726, 13.378317581667481],
#       [122.17847494213397, 13.634589634241497],
#       [122.37762576516074, 13.77059624007451],
#       [122.56144950485401, 13.514324187500495]]]},
#    'satellite_name': 'diwata-1',
#    'payload': 'smi',
#    'cloudcover': None,
#    'capture_time': '2018-06-22T05:31:10.005041',
#    'wavelength': 610.0,
#    'published_time': None,
#    'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053110005_V610/D1_SMI_2018-06-22T053110005_V610.zip',
#     'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053110005_V610/D1_SMI_2018-06-22T053110005_V610-thumb.png'},
#    'image_quality': None,
#    'bands': {'L1A': 'D1_SMI_2018-06-22T053110005_V610_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053110005_V610_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053110005_V610_L1C.tif'},
#    'day_or_night': '',
#    'sun_elevation': 64.61479849180371,
#    'sun_azimuth': 296.4679672642852,
#    'products': {'L1A': 'D1_SMI_2018-06-22T053110005_V610_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053110005_V610_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053110005_V610_L1C.tif'},
#    'satellite_color': None,
#    'payload_color': None,
#    'mission_id': None,
#    'mission_name': None,
#    'mission_start_time': None},
#   {'scene_id': 'D1_SMI_2018-06-22T053109055_V650',
#    'scene_center': {'type': 'Point',
#     'coordinates': [122.34978777239682, 13.599565078318964]},
#    'scene_footprint': {'type': 'Polygon',
#     'coordinates': [[[122.54114598522563, 13.539595104861707],
#       [122.34226431507734, 13.40316777739933],
#       [122.15842955956802, 13.659535051776217],
#       [122.3573112297163, 13.795962379238592],
#       [122.54114598522563, 13.539595104861707]]]},
#    'satellite_name': 'diwata-1',
#    'payload': 'smi',
#    'cloudcover': None,
#    'capture_time': '2018-06-22T05:31:09.055041',
#    'wavelength': 650.0,
#    'published_time': None,
#    'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053109055_V650/D1_SMI_2018-06-22T053109055_V650.zip',
#     'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053109055_V650/D1_SMI_2018-06-22T053109055_V650-thumb.png'},
#    'image_quality': None,
#    'bands': {'L1A': 'D1_SMI_2018-06-22T053109055_V650_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053109055_V650_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053109055_V650_L1C.tif'},
#    'day_or_night': '',
#    'sun_elevation': 64.64703698468618,
#    'sun_azimuth': 296.43684892242663,
#    'products': {'L1A': 'D1_SMI_2018-06-22T053109055_V650_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053109055_V650_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053109055_V650_L1C.tif'},
#    'satellite_color': None,
#    'payload_color': None,
#    'mission_id': None,
#    'mission_name': None,
#    'mission_start_time': None},
#   {'scene_id': 'D1_SMI_2018-06-22T053109005_V690',
#    'scene_center': {'type': 'Point',
#     'coordinates': [122.32964205098705, 13.624652969211866]},
#    'scene_footprint': {'type': 'Polygon',
#     'coordinates': [[[122.52083683573875, 13.564782286648681],
#       [122.32234089182352, 13.427923595675988],
#       [122.13844726623533, 13.684523651775056],
#       [122.33694321015057, 13.821382342747748],
#       [122.52083683573875, 13.564782286648681]]]},
#    'satellite_name': 'diwata-1',
#    'payload': 'smi',
#    'cloudcover': None,
#    'capture_time': '2018-06-22T05:31:09.005041',
#    'wavelength': 690.0,
#    'published_time': None,
#    'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053109005_V690/D1_SMI_2018-06-22T053109005_V690.zip',
#     'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053109005_V690/D1_SMI_2018-06-22T053109005_V690-thumb.png'},
#    'image_quality': None,
#    'bands': {'L1A': 'D1_SMI_2018-06-22T053109005_V690_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053109005_V690_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053109005_V690_L1C.tif'},
#    'day_or_night': '',
#    'sun_elevation': 64.67597649619952,
#    'sun_azimuth': 296.40316242944016,
#    'products': {'L1A': 'D1_SMI_2018-06-22T053109005_V690_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053109005_V690_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053109005_V690_L1C.tif'},
#    'satellite_color': None,
#    'payload_color': None,
#    'mission_id': None,
#    'mission_name': None,
#    'mission_start_time': None},
#   {'scene_id': 'D1_SMI_2018-06-22T053108055_V710',
#    'scene_center': {'type': 'Point',
#     'coordinates': [122.30948361858869, 13.649783522077561]},
#    'scene_footprint': {'type': 'Polygon',
#     'coordinates': [[[122.50062565456784, 13.589940395357985],
#       [122.30241298699586, 13.452761006114647],
#       [122.11834158260957, 13.709626648797137],
#       [122.31655425018154, 13.846806038040475],
#       [122.50062565456784, 13.589940395357985]]]},
#    'satellite_name': 'diwata-1',
#    'payload': 'smi',
#    'cloudcover': None,
#    'capture_time': '2018-06-22T05:31:08.055041',
#    'wavelength': 710.0,
#    'published_time': None,
#    'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053108055_V710/D1_SMI_2018-06-22T053108055_V710.zip',
#     'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053108055_V710/D1_SMI_2018-06-22T053108055_V710-thumb.png'},
#    'image_quality': None,
#    'bands': {'L1A': 'D1_SMI_2018-06-22T053108055_V710_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053108055_V710_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053108055_V710_L1C.tif'},
#    'day_or_night': '',
#    'sun_elevation': 64.70816717775779,
#    'sun_azimuth': 296.37190748379817,
#    'products': {'L1A': 'D1_SMI_2018-06-22T053108055_V710_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053108055_V710_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053108055_V710_L1C.tif'},
#    'satellite_color': None,
#    'payload_color': None,
#    'mission_id': None,
#    'mission_name': None,
#    'mission_start_time': None},
#   {'scene_id': 'D1_SMI_2018-06-22T053108005_V670',
#    'scene_center': {'type': 'Point',
#     'coordinates': [122.28910844450009, 13.675018241900474]},
#    'scene_footprint': {'type': 'Polygon',
#     'coordinates': [[[122.48042987398583, 13.615182127367211],
#       [122.28191294572028, 13.477785818346302],
#       [122.09778701501435, 13.734854356433738],
#       [122.2963039432799, 13.872250665454647],
#       [122.48042987398583, 13.615182127367211]]]},
#    'satellite_name': 'diwata-1',
#    'payload': 'smi',
#    'cloudcover': None,
#    'capture_time': '2018-06-22T05:31:08.005041',
#    'wavelength': 670.0,
#    'published_time': None,
#    'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053108005_V670/D1_SMI_2018-06-22T053108005_V670.zip',
#     'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053108005_V670/D1_SMI_2018-06-22T053108005_V670-thumb.png'},
#    'image_quality': None,
#    'bands': {'L1A': 'D1_SMI_2018-06-22T053108005_V670_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053108005_V670_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053108005_V670_L1C.tif'},
#    'day_or_night': '',
#    'sun_elevation': 64.73723646286537,
#    'sun_azimuth': 296.3378931417315,
#    'products': {'L1A': 'D1_SMI_2018-06-22T053108005_V670_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053108005_V670_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053108005_V670_L1C.tif'},
#    'satellite_color': None,
#    'payload_color': None,
#    'mission_id': None,
#    'mission_name': None,
#    'mission_start_time': None},
#   {'scene_id': 'D1_SMI_2018-06-22T053107055_V550',
#    'scene_center': {'type': 'Point',
#     'coordinates': [122.26877277182659, 13.700192005493216]},
#    'scene_footprint': {'type': 'Polygon',
#     'coordinates': [[[122.46027800306109, 13.640288205351045],
#       [122.2618025431625, 13.502412697844857],
#       [122.07726754059212, 13.760095805635391],
#       [122.2757430004907, 13.897971313141579],
#       [122.46027800306109, 13.640288205351045]]]},
#    'satellite_name': 'diwata-1',
#    'payload': 'smi',
#    'cloudcover': None,
#    'capture_time': '2018-06-22T05:31:07.055041',
#    'wavelength': 550.0,
#    'published_time': None,
#    'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053107055_V550/D1_SMI_2018-06-22T053107055_V550.zip',
#     'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053107055_V550/D1_SMI_2018-06-22T053107055_V550-thumb.png'},
#    'image_quality': None,
#    'bands': {'L1A': 'D1_SMI_2018-06-22T053107055_V550_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053107055_V550_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053107055_V550_L1C.tif'},
#    'day_or_night': '',
#    'sun_elevation': 64.76950910669368,
#    'sun_azimuth': 296.30647427154946,
#    'products': {'L1A': 'D1_SMI_2018-06-22T053107055_V550_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053107055_V550_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053107055_V550_L1C.tif'},
#    'satellite_color': None,
#    'payload_color': None,
#    'mission_id': None,
#    'mission_name': None,
#    'mission_start_time': None},
#   {'scene_id': 'D1_SMI_2018-06-22T053107005_V490',
#    'scene_center': {'type': 'Point',
#     'coordinates': [122.24836129080721, 13.725509064435212]},
#    'scene_footprint': {'type': 'Polygon',
#     'coordinates': [[[122.44001803569783, 13.665461871021357],
#       [122.24181207362744, 13.52713309841376],
#       [122.05670454591657, 13.78555625784907],
#       [122.25491050798695, 13.923885030456665],
#       [122.44001803569783, 13.665461871021357]]]},
#    'satellite_name': 'diwata-1',
#    'payload': 'smi',
#    'cloudcover': None,
#    'capture_time': '2018-06-22T05:31:07.005041',
#    'wavelength': 490.0,
#    'published_time': None,
#    'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053107005_V490/D1_SMI_2018-06-22T053107005_V490.zip',
#     'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053107005_V490/D1_SMI_2018-06-22T053107005_V490-thumb.png'},
#    'image_quality': None,
#    'bands': {'L1A': 'D1_SMI_2018-06-22T053107005_V490_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053107005_V490_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053107005_V490_L1C.tif'},
#    'day_or_night': '',
#    'sun_elevation': 64.79863986350378,
#    'sun_azimuth': 296.27226868418603,
#    'products': {'L1A': 'D1_SMI_2018-06-22T053107005_V490_L1A.tif',
#     'L1B': 'D1_SMI_2018-06-22T053107005_V490_L1B.tif',
#     'L1C': 'D1_SMI_2018-06-22T053107005_V490_L1C.tif'},
#    'satellite_color': None,
#    'payload_color': None,
#    'mission_id': None,
#    'mission_name': None,
#    'mission_start_time': None}],
#  'meta': {'total_count': 1548,
#   'total_pages': 154.8,
#   'page': 1,
#   'page_size': 10},
#  'links': {'histogram': 'https://api.orange.phl-microsat.xyz/scenes/histogram?',
#   'self': 'https://api.orange.phl-microsat.xyz/scenes?page=1&limit=10',
#   'first': 'https://api.orange.phl-microsat.xyz/scenes?page=1&limit=10',
#   'prev': 'https://api.orange.phl-microsat.xyz/scenes?page=1&limit=10',
#   'next': 'https://api.orange.phl-microsat.xyz/scenes?page=2&limit=10',
#   'last': 'https://api.orange.phl-microsat.xyz/scenes?page=154.8&limit=10'}}

# %% [markdown]
# ### Inspect Results
#
# The response returns a JSON file with two parts, the data and the meta. Let's look at the data part.

# %%
data = r.json()['data']
data
# Out:
# [{'scene_id': 'D1_SMI_2018-06-22T053111055_V550',
#   'scene_center': {'type': 'Point',
#    'coordinates': [122.43041191598462, 13.499050232561672]},
#   'scene_footprint': {'type': 'Polygon',
#    'coordinates': [[[122.62270772244743, 13.438726191427726],
#      [122.42199776143877, 13.303514648530331],
#      [122.23811610952181, 13.559374273695617],
#      [122.43882607053047, 13.694585816593012],
#      [122.62270772244743, 13.438726191427726]]]},
#   'satellite_name': 'diwata-1',
#   'payload': 'smi',
#   'cloudcover': None,
#   'capture_time': '2018-06-22T05:31:11.055041',
#   'wavelength': 550.0,
#   'published_time': None,
#   'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053111055_V550/D1_SMI_2018-06-22T053111055_V550.zip',
#    'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053111055_V550/D1_SMI_2018-06-22T053111055_V550-thumb.png'},
#   'image_quality': None,
#   'bands': {'L1A': 'D1_SMI_2018-06-22T053111055_V550_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053111055_V550_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053111055_V550_L1C.tif'},
#   'day_or_night': '',
#   'sun_elevation': 64.52449656078697,
#   'sun_azimuth': 296.56580289395646,
#   'products': {'L1A': 'D1_SMI_2018-06-22T053111055_V550_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053111055_V550_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053111055_V550_L1C.tif'},
#   'satellite_color': None,
#   'payload_color': None,
#   'mission_id': None,
#   'mission_name': None,
#   'mission_start_time': None},
#  {'scene_id': 'D1_SMI_2018-06-22T053111005_V490',
#   'scene_center': {'type': 'Point',
#    'coordinates': [122.41037919898515, 13.524257425972182]},
#   'scene_footprint': {'type': 'Polygon',
#    'coordinates': [[[122.60181321555628, 13.463561180795324],
#      [122.4026086729601, 13.328684017512556],
#      [122.21894518241409, 13.584953671149043],
#      [122.41814972501025, 13.71983083443181],
#      [122.60181321555628, 13.463561180795324]]]},
#   'satellite_name': 'diwata-1',
#   'payload': 'smi',
#   'cloudcover': None,
#   'capture_time': '2018-06-22T05:31:11.005041',
#   'wavelength': 490.0,
#   'published_time': None,
#   'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053111005_V490/D1_SMI_2018-06-22T053111005_V490.zip',
#    'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053111005_V490/D1_SMI_2018-06-22T053111005_V490-thumb.png'},
#   'image_quality': None,
#   'bands': {'L1A': 'D1_SMI_2018-06-22T053111005_V490_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053111005_V490_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053111005_V490_L1C.tif'},
#   'day_or_night': '',
#   'sun_elevation': 64.55355218551621,
#   'sun_azimuth': 296.53258085383357,
#   'products': {'L1A': 'D1_SMI_2018-06-22T053111005_V490_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053111005_V490_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053111005_V490_L1C.tif'},
#   'satellite_color': None,
#   'payload_color': None,
#   'mission_id': None,
#   'mission_name': None,
#   'mission_start_time': None},
#  {'scene_id': 'D1_SMI_2018-06-22T053110055_V530',
#   'scene_center': {'type': 'Point',
#    'coordinates': [122.39014773697839, 13.549283385236455]},
#   'scene_footprint': {'type': 'Polygon',
#    'coordinates': [[[122.58171960927119, 13.48891446156232],
#      [122.38243473264716, 13.353239535978396],
#      [122.19857586468555, 13.609652308910583],
#      [122.39786074130959, 13.745327234494505],
#      [122.58171960927119, 13.48891446156232]]]},
#   'satellite_name': 'diwata-1',
#   'payload': 'smi',
#   'cloudcover': None,
#   'capture_time': '2018-06-22T05:31:10.055041',
#   'wavelength': 530.0,
#   'published_time': None,
#   'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053110055_V530/D1_SMI_2018-06-22T053110055_V530.zip',
#    'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053110055_V530/D1_SMI_2018-06-22T053110055_V530-thumb.png'},
#   'image_quality': None,
#   'bands': {'L1A': 'D1_SMI_2018-06-22T053110055_V530_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053110055_V530_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053110055_V530_L1C.tif'},
#   'day_or_night': '',
#   'sun_elevation': 64.58577701802034,
#   'sun_azimuth': 296.5016810780284,
#   'products': {'L1A': 'D1_SMI_2018-06-22T053110055_V530_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053110055_V530_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053110055_V530_L1C.tif'},
#   'satellite_color': None,
#   'payload_color': None,
#   'mission_id': None,
#   'mission_name': None,
#   'mission_start_time': None},
#  {'scene_id': 'D1_SMI_2018-06-22T053110005_V610',
#   'scene_center': {'type': 'Point',
#    'coordinates': [122.36996222349399, 13.574456910870994]},
#   'scene_footprint': {'type': 'Polygon',
#    'coordinates': [[[122.56144950485401, 13.514324187500495],
#      [122.36229868182726, 13.378317581667481],
#      [122.17847494213397, 13.634589634241497],
#      [122.37762576516074, 13.77059624007451],
#      [122.56144950485401, 13.514324187500495]]]},
#   'satellite_name': 'diwata-1',
#   'payload': 'smi',
#   'cloudcover': None,
#   'capture_time': '2018-06-22T05:31:10.005041',
#   'wavelength': 610.0,
#   'published_time': None,
#   'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053110005_V610/D1_SMI_2018-06-22T053110005_V610.zip',
#    'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053110005_V610/D1_SMI_2018-06-22T053110005_V610-thumb.png'},
#   'image_quality': None,
#   'bands': {'L1A': 'D1_SMI_2018-06-22T053110005_V610_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053110005_V610_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053110005_V610_L1C.tif'},
#   'day_or_night': '',
#   'sun_elevation': 64.61479849180371,
#   'sun_azimuth': 296.4679672642852,
#   'products': {'L1A': 'D1_SMI_2018-06-22T053110005_V610_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053110005_V610_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053110005_V610_L1C.tif'},
#   'satellite_color': None,
#   'payload_color': None,
#   'mission_id': None,
#   'mission_name': None,
#   'mission_start_time': None},
#  {'scene_id': 'D1_SMI_2018-06-22T053109055_V650',
#   'scene_center': {'type': 'Point',
#    'coordinates': [122.34978777239682, 13.599565078318964]},
#   'scene_footprint': {'type': 'Polygon',
#    'coordinates': [[[122.54114598522563, 13.539595104861707],
#      [122.34226431507734, 13.40316777739933],
#      [122.15842955956802, 13.659535051776217],
#      [122.3573112297163, 13.795962379238592],
#      [122.54114598522563, 13.539595104861707]]]},
#   'satellite_name': 'diwata-1',
#   'payload': 'smi',
#   'cloudcover': None,
#   'capture_time': '2018-06-22T05:31:09.055041',
#   'wavelength': 650.0,
#   'published_time': None,
#   'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053109055_V650/D1_SMI_2018-06-22T053109055_V650.zip',
#    'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053109055_V650/D1_SMI_2018-06-22T053109055_V650-thumb.png'},
#   'image_quality': None,
#   'bands': {'L1A': 'D1_SMI_2018-06-22T053109055_V650_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053109055_V650_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053109055_V650_L1C.tif'},
#   'day_or_night': '',
#   'sun_elevation': 64.64703698468618,
#   'sun_azimuth': 296.43684892242663,
#   'products': {'L1A': 'D1_SMI_2018-06-22T053109055_V650_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053109055_V650_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053109055_V650_L1C.tif'},
#   'satellite_color': None,
#   'payload_color': None,
#   'mission_id': None,
#   'mission_name': None,
#   'mission_start_time': None},
#  {'scene_id': 'D1_SMI_2018-06-22T053109005_V690',
#   'scene_center': {'type': 'Point',
#    'coordinates': [122.32964205098705, 13.624652969211866]},
#   'scene_footprint': {'type': 'Polygon',
#    'coordinates': [[[122.52083683573875, 13.564782286648681],
#      [122.32234089182352, 13.427923595675988],
#      [122.13844726623533, 13.684523651775056],
#      [122.33694321015057, 13.821382342747748],
#      [122.52083683573875, 13.564782286648681]]]},
#   'satellite_name': 'diwata-1',
#   'payload': 'smi',
#   'cloudcover': None,
#   'capture_time': '2018-06-22T05:31:09.005041',
#   'wavelength': 690.0,
#   'published_time': None,
#   'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053109005_V690/D1_SMI_2018-06-22T053109005_V690.zip',
#    'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053109005_V690/D1_SMI_2018-06-22T053109005_V690-thumb.png'},
#   'image_quality': None,
#   'bands': {'L1A': 'D1_SMI_2018-06-22T053109005_V690_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053109005_V690_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053109005_V690_L1C.tif'},
#   'day_or_night': '',
#   'sun_elevation': 64.67597649619952,
#   'sun_azimuth': 296.40316242944016,
#   'products': {'L1A': 'D1_SMI_2018-06-22T053109005_V690_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053109005_V690_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053109005_V690_L1C.tif'},
#   'satellite_color': None,
#   'payload_color': None,
#   'mission_id': None,
#   'mission_name': None,
#   'mission_start_time': None},
#  {'scene_id': 'D1_SMI_2018-06-22T053108055_V710',
#   'scene_center': {'type': 'Point',
#    'coordinates': [122.30948361858869, 13.649783522077561]},
#   'scene_footprint': {'type': 'Polygon',
#    'coordinates': [[[122.50062565456784, 13.589940395357985],
#      [122.30241298699586, 13.452761006114647],
#      [122.11834158260957, 13.709626648797137],
#      [122.31655425018154, 13.846806038040475],
#      [122.50062565456784, 13.589940395357985]]]},
#   'satellite_name': 'diwata-1',
#   'payload': 'smi',
#   'cloudcover': None,
#   'capture_time': '2018-06-22T05:31:08.055041',
#   'wavelength': 710.0,
#   'published_time': None,
#   'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053108055_V710/D1_SMI_2018-06-22T053108055_V710.zip',
#    'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053108055_V710/D1_SMI_2018-06-22T053108055_V710-thumb.png'},
#   'image_quality': None,
#   'bands': {'L1A': 'D1_SMI_2018-06-22T053108055_V710_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053108055_V710_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053108055_V710_L1C.tif'},
#   'day_or_night': '',
#   'sun_elevation': 64.70816717775779,
#   'sun_azimuth': 296.37190748379817,
#   'products': {'L1A': 'D1_SMI_2018-06-22T053108055_V710_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053108055_V710_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053108055_V710_L1C.tif'},
#   'satellite_color': None,
#   'payload_color': None,
#   'mission_id': None,
#   'mission_name': None,
#   'mission_start_time': None},
#  {'scene_id': 'D1_SMI_2018-06-22T053108005_V670',
#   'scene_center': {'type': 'Point',
#    'coordinates': [122.28910844450009, 13.675018241900474]},
#   'scene_footprint': {'type': 'Polygon',
#    'coordinates': [[[122.48042987398583, 13.615182127367211],
#      [122.28191294572028, 13.477785818346302],
#      [122.09778701501435, 13.734854356433738],
#      [122.2963039432799, 13.872250665454647],
#      [122.48042987398583, 13.615182127367211]]]},
#   'satellite_name': 'diwata-1',
#   'payload': 'smi',
#   'cloudcover': None,
#   'capture_time': '2018-06-22T05:31:08.005041',
#   'wavelength': 670.0,
#   'published_time': None,
#   'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053108005_V670/D1_SMI_2018-06-22T053108005_V670.zip',
#    'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053108005_V670/D1_SMI_2018-06-22T053108005_V670-thumb.png'},
#   'image_quality': None,
#   'bands': {'L1A': 'D1_SMI_2018-06-22T053108005_V670_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053108005_V670_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053108005_V670_L1C.tif'},
#   'day_or_night': '',
#   'sun_elevation': 64.73723646286537,
#   'sun_azimuth': 296.3378931417315,
#   'products': {'L1A': 'D1_SMI_2018-06-22T053108005_V670_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053108005_V670_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053108005_V670_L1C.tif'},
#   'satellite_color': None,
#   'payload_color': None,
#   'mission_id': None,
#   'mission_name': None,
#   'mission_start_time': None},
#  {'scene_id': 'D1_SMI_2018-06-22T053107055_V550',
#   'scene_center': {'type': 'Point',
#    'coordinates': [122.26877277182659, 13.700192005493216]},
#   'scene_footprint': {'type': 'Polygon',
#    'coordinates': [[[122.46027800306109, 13.640288205351045],
#      [122.2618025431625, 13.502412697844857],
#      [122.07726754059212, 13.760095805635391],
#      [122.2757430004907, 13.897971313141579],
#      [122.46027800306109, 13.640288205351045]]]},
#   'satellite_name': 'diwata-1',
#   'payload': 'smi',
#   'cloudcover': None,
#   'capture_time': '2018-06-22T05:31:07.055041',
#   'wavelength': 550.0,
#   'published_time': None,
#   'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053107055_V550/D1_SMI_2018-06-22T053107055_V550.zip',
#    'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053107055_V550/D1_SMI_2018-06-22T053107055_V550-thumb.png'},
#   'image_quality': None,
#   'bands': {'L1A': 'D1_SMI_2018-06-22T053107055_V550_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053107055_V550_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053107055_V550_L1C.tif'},
#   'day_or_night': '',
#   'sun_elevation': 64.76950910669368,
#   'sun_azimuth': 296.30647427154946,
#   'products': {'L1A': 'D1_SMI_2018-06-22T053107055_V550_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053107055_V550_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053107055_V550_L1C.tif'},
#   'satellite_color': None,
#   'payload_color': None,
#   'mission_id': None,
#   'mission_name': None,
#   'mission_start_time': None},
#  {'scene_id': 'D1_SMI_2018-06-22T053107005_V490',
#   'scene_center': {'type': 'Point',
#    'coordinates': [122.24836129080721, 13.725509064435212]},
#   'scene_footprint': {'type': 'Polygon',
#    'coordinates': [[[122.44001803569783, 13.665461871021357],
#      [122.24181207362744, 13.52713309841376],
#      [122.05670454591657, 13.78555625784907],
#      [122.25491050798695, 13.923885030456665],
#      [122.44001803569783, 13.665461871021357]]]},
#   'satellite_name': 'diwata-1',
#   'payload': 'smi',
#   'cloudcover': None,
#   'capture_time': '2018-06-22T05:31:07.005041',
#   'wavelength': 490.0,
#   'published_time': None,
#   'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053107005_V490/D1_SMI_2018-06-22T053107005_V490.zip',
#    'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053107005_V490/D1_SMI_2018-06-22T053107005_V490-thumb.png'},
#   'image_quality': None,
#   'bands': {'L1A': 'D1_SMI_2018-06-22T053107005_V490_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053107005_V490_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053107005_V490_L1C.tif'},
#   'day_or_night': '',
#   'sun_elevation': 64.79863986350378,
#   'sun_azimuth': 296.27226868418603,
#   'products': {'L1A': 'D1_SMI_2018-06-22T053107005_V490_L1A.tif',
#    'L1B': 'D1_SMI_2018-06-22T053107005_V490_L1B.tif',
#    'L1C': 'D1_SMI_2018-06-22T053107005_V490_L1C.tif'},
#   'satellite_color': None,
#   'payload_color': None,
#   'mission_id': None,
#   'mission_name': None,
#   'mission_start_time': None}]

# %% [markdown]
# ### Row Contents
#
# The data returns a list of dictionaries, each with information about a specific image. Each dictionary has the following information
#
# * scene_id
# * scene_center
# * scene_footprint
# * satellite_name
# * payload
# * cloudcover
# * capture_time
# * wavelength
# * published_time
# * links
# * image_quality
# * bands
# * day_or_night
# * products
# * satellite_color
# * payload_color
# * mission_id
# * mission_name
# * mission_start_time

# %% [markdown]
# ### Inspect a Sample Image

# %%
sample = data[0]
sample
# Out:
# {'scene_id': 'D1_SMI_2018-06-22T053111055_V550',
#  'scene_center': {'type': 'Point',
#   'coordinates': [122.43041191598462, 13.499050232561672]},
#  'scene_footprint': {'type': 'Polygon',
#   'coordinates': [[[122.62270772244743, 13.438726191427726],
#     [122.42199776143877, 13.303514648530331],
#     [122.23811610952181, 13.559374273695617],
#     [122.43882607053047, 13.694585816593012],
#     [122.62270772244743, 13.438726191427726]]]},
#  'satellite_name': 'diwata-1',
#  'payload': 'smi',
#  'cloudcover': None,
#  'capture_time': '2018-06-22T05:31:11.055041',
#  'wavelength': 550.0,
#  'published_time': None,
#  'links': {'bundle_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053111055_V550/D1_SMI_2018-06-22T053111055_V550.zip',
#   'thumbnail_url': 'https://phl-microsat-storage.dream.upd.edu.ph/images/diwata-1/D1_SMI_2018-06-22T053111055_V550/D1_SMI_2018-06-22T053111055_V550-thumb.png'},
#  'image_quality': None,
#  'bands': {'L1A': 'D1_SMI_2018-06-22T053111055_V550_L1A.tif',
#   'L1B': 'D1_SMI_2018-06-22T053111055_V550_L1B.tif',
#   'L1C': 'D1_SMI_2018-06-22T053111055_V550_L1C.tif'},
#  'day_or_night': '',
#  'sun_elevation': 64.52449656078697,
#  'sun_azimuth': 296.56580289395646,
#  'products': {'L1A': 'D1_SMI_2018-06-22T053111055_V550_L1A.tif',
#   'L1B': 'D1_SMI_2018-06-22T053111055_V550_L1B.tif',
#   'L1C': 'D1_SMI_2018-06-22T053111055_V550_L1C.tif'},
#  'satellite_color': None,
#  'payload_color': None,
#  'mission_id': None,
#  'mission_name': None,
#  'mission_start_time': None}

# %% [markdown]
# ### Setup Folium
#
# To visualize shapes, we'll be using **Folium**, a Python library for plotting maps using `Leaflet.js`.

# %%
import folium

COUNTRY_CENTER = [12.8797, 121.7740]
m = folium.Map(location=COUNTRY_CENTER, zoom_start=6)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Geometries
#
# There are two geometry attributes included in each item: `scene_footprint` and `scene_center`

# %% [markdown]
# #### Geometry: Scene Footprint
#
# This is the actual area covered by the image on the ground. It is represented as a GeoJSON polygon geometry.

# %%
footprint = sample['scene_footprint']
footprint
# Out:
# {'type': 'Polygon',
#  'coordinates': [[[122.62270772244743, 13.438726191427726],
#    [122.42199776143877, 13.303514648530331],
#    [122.23811610952181, 13.559374273695617],
#    [122.43882607053047, 13.694585816593012],
#    [122.62270772244743, 13.438726191427726]]]}

# %%
folium.GeoJson(
    footprint,
    name='footprint'
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Geometry: Scene Center
#
# It's the centroid of the footprint on the ground. It is represented as a GeoJSON point.

# %%
scene_center = sample['scene_center']
scene_center
# Out:
# {'type': 'Point', 'coordinates': [122.43041191598462, 13.499050232561672]}

# %%
m = folium.Map(location=COUNTRY_CENTER, zoom_start=5)

folium.GeoJson(
    scene_center,
    name='scene_center'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Filters
#
# The API also allows filtering of results
#
# #### Basic Filters
# | **Parameter**            | **Description**                                                                                           | **Example**                                           |
# |--------------------------|-----------------------------------------------------------------------------------------------------------|-------------------------------------------------------|
# | payload                  | Filter by payload. Sample payloads are: 'hpt', 'smi', 'mfc'. Multiple allowed.                            | `/scenes?payload=smi,hpt`                             |
# | satellite_name           | Filter by satellite name. Multiple allowed.                                                               | `/scenes?satellite_name=diwata-1,landsat8`             |
# | since                    | Return scenes captured on or after specified date (UTC)                                                   | `/scenes?since=2016-01-01T00:00:00Z`                  |
# | until                    | Return scenes captured on or before specified date (UTC)                                                  | `/scenes?until=2016-01-01T00:00:00Z`                  |
#
# #### Geographical Filters
# | **Parameter**            | **Description**                                                                                           | **Example**                                           |
# |--------------------------|-----------------------------------------------------------------------------------------------------------|-------------------------------------------------------|
# | geo_bounding_box         | Returns scenes that intersect with a bounding box                                                         | `/scenes?geo_bounding_box=118.30078,16.10915,128.6718,9.34067` |
# | geo_point                | Returns scenes that encloses a specified pinned point                                                     | `/scenes?geo_point=121.11328,15.05090`  |

# %% [markdown]
# ## GET /scenes/histogram <a class="anchor" id="histogram"></a>
#
# This endpoint returns the number of scenes per day/number of days. `bucket_size` indicates the number of days to group the results by.

# %%
r = requests.get(API_URL + '/scenes/histogram?bucket_size=7')
r.json()
# Out:
# {'data': [{'date': '2016-11-10T00:00:00.000Z', 'count': 24},
#   {'date': '2016-11-17T00:00:00.000Z', 'count': 0},
#   {'date': '2016-11-24T00:00:00.000Z', 'count': 0},
#   {'date': '2016-12-01T00:00:00.000Z', 'count': 0},
#   {'date': '2016-12-08T00:00:00.000Z', 'count': 0},
#   {'date': '2016-12-15T00:00:00.000Z', 'count': 31},
#   {'date': '2016-12-22T00:00:00.000Z', 'count': 0},
#   {'date': '2016-12-29T00:00:00.000Z', 'count': 10},
#   {'date': '2017-01-05T00:00:00.000Z', 'count': 0},
#   {'date': '2017-01-12T00:00:00.000Z', 'count': 0},
#   {'date': '2017-01-19T00:00:00.000Z', 'count': 0},
#   {'date': '2017-01-26T00:00:00.000Z', 'count': 0},
#   {'date': '2017-02-02T00:00:00.000Z', 'count': 70},
#   {'date': '2017-02-09T00:00:00.000Z', 'count': 0},
#   {'date': '2017-02-16T00:00:00.000Z', 'count': 0},
#   {'date': '2017-02-23T00:00:00.000Z', 'count': 14},
#   {'date': '2017-03-02T00:00:00.000Z', 'count': 17},
#   {'date': '2017-03-09T00:00:00.000Z', 'count': 0},
#   {'date': '2017-03-16T00:00:00.000Z', 'count': 0},
#   {'date': '2017-03-23T00:00:00.000Z', 'count': 0},
#   {'date': '2017-03-30T00:00:00.000Z', 'count': 36},
#   {'date': '2017-04-06T00:00:00.000Z', 'count': 117},
#   {'date': '2017-04-13T00:00:00.000Z', 'count': 48},
#   {'date': '2017-04-20T00:00:00.000Z', 'count': 138},
#   {'date': '2017-04-27T00:00:00.000Z', 'count': 0},
#   {'date': '2017-05-04T00:00:00.000Z', 'count': 0},
#   {'date': '2017-05-11T00:00:00.000Z', 'count': 45},
#   {'date': '2017-05-18T00:00:00.000Z', 'count': 0},
#   {'date': '2017-05-25T00:00:00.000Z', 'count': 0},
#   {'date': '2017-06-01T00:00:00.000Z', 'count': 0},
#   {'date': '2017-06-08T00:00:00.000Z', 'count': 35},
#   {'date': '2017-06-15T00:00:00.000Z', 'count': 72},
#   {'date': '2017-06-22T00:00:00.000Z', 'count': 0},
#   {'date': '2017-06-29T00:00:00.000Z', 'count': 71},
#   {'date': '2017-07-06T00:00:00.000Z', 'count': 34},
#   {'date': '2017-07-13T00:00:00.000Z', 'count': 0},
#   {'date': '2017-07-20T00:00:00.000Z', 'count': 0},
#   {'date': '2017-07-27T00:00:00.000Z', 'count': 0},
#   {'date': '2017-08-03T00:00:00.000Z', 'count': 59},
#   {'date': '2017-08-10T00:00:00.000Z', 'count': 118},
#   {'date': '2017-08-17T00:00:00.000Z', 'count': 0},
#   {'date': '2017-08-24T00:00:00.000Z', 'count': 0},
#   {'date': '2017-08-31T00:00:00.000Z', 'count': 0},
#   {'date': '2017-09-07T00:00:00.000Z', 'count': 0},
#   {'date': '2017-09-14T00:00:00.000Z', 'count': 0},
#   {'date': '2017-09-21T00:00:00.000Z', 'count': 0},
#   {'date': '2017-09-28T00:00:00.000Z', 'count': 0},
#   {'date': '2017-10-05T00:00:00.000Z', 'count': 0},
#   {'date': '2017-10-12T00:00:00.000Z', 'count': 0},
#   {'date': '2017-10-19T00:00:00.000Z', 'count': 0},
#   {'date': '2017-10-26T00:00:00.000Z', 'count': 0},
#   {'date': '2017-11-02T00:00:00.000Z', 'count': 0},
#   {'date': '2017-11-09T00:00:00.000Z', 'count': 0},
#   {'date': '2017-11-16T00:00:00.000Z', 'count': 0},
#   {'date': '2017-11-23T00:00:00.000Z', 'count': 0},
#   {'date': '2017-11-30T00:00:00.000Z', 'count': 0},
#   {'date': '2017-12-07T00:00:00.000Z', 'count': 0},
#   {'date': '2017-12-14T00:00:00.000Z', 'count': 0},
#   {'date': '2017-12-21T00:00:00.000Z', 'count': 0},
#   {'date': '2017-12-28T00:00:00.000Z', 'count': 0},
#   {'date': '2018-01-04T00:00:00.000Z', 'count': 0},
#   {'date': '2018-01-11T00:00:00.000Z', 'count': 0},
#   {'date': '2018-01-18T00:00:00.000Z', 'count': 0},
#   {'date': '2018-01-25T00:00:00.000Z', 'count': 46},
#   {'date': '2018-02-01T00:00:00.000Z', 'count': 0},
#   {'date': '2018-02-08T00:00:00.000Z', 'count': 0},
#   {'date': '2018-02-15T00:00:00.000Z', 'count': 60},
#   {'date': '2018-02-22T00:00:00.000Z', 'count': 0},
#   {'date': '2018-03-01T00:00:00.000Z', 'count': 0},
#   {'date': '2018-03-08T00:00:00.000Z', 'count': 77},
#   {'date': '2018-03-15T00:00:00.000Z', 'count': 0},
#   {'date': '2018-03-22T00:00:00.000Z', 'count': 0},
#   {'date': '2018-03-29T00:00:00.000Z', 'count': 120},
#   {'date': '2018-04-05T00:00:00.000Z', 'count': 43},
#   {'date': '2018-04-12T00:00:00.000Z', 'count': 58},
#   {'date': '2018-04-19T00:00:00.000Z', 'count': 57},
#   {'date': '2018-04-26T00:00:00.000Z', 'count': 0},
#   {'date': '2018-05-03T00:00:00.000Z', 'count': 41},
#   {'date': '2018-05-10T00:00:00.000Z', 'count': 0},
#   {'date': '2018-05-17T00:00:00.000Z', 'count': 27},
#   {'date': '2018-05-24T00:00:00.000Z', 'count': 53},
#   {'date': '2018-05-31T00:00:00.000Z', 'count': 0},
#   {'date': '2018-06-07T00:00:00.000Z', 'count': 0},
#   {'date': '2018-06-14T00:00:00.000Z', 'count': 0},
#   {'date': '2018-06-21T00:00:00.000Z', 'count': 27}],
#  'meta': {'bucket_count': 85, 'bucket_size': 7.0},
#  'links': {'self': 'https://api.orange.phl-microsat.xyz/scenes/histogram?'}}

# %% [markdown]
# Filters for the GET /scenes endpoint also work here!

# %% [markdown]
# ## GET /scenes/geohash <a class="anchor" id="geohash"></a>
#
# This endpoint returns the number of scenes grouped by geohash.

# %%
r = requests.get(API_URL + '/scenes/geohash')
r.json()
# Out:
# {'data': [{'key': 'wdw',
#    'count': 243,
#    'bbox': [[14.0625, 120.9375], [15.46875, 122.34375]]},
#   {'key': 'wf0',
#    'count': 130,
#    'bbox': [[11.25, 123.75], [12.65625, 125.15625]]},
#   {'key': 'wdr',
#    'count': 121,
#    'bbox': [[12.65625, 122.34375], [14.0625, 123.75]]},
#   {'key': 'wdq',
#    'count': 108,
#    'bbox': [[12.65625, 120.9375], [14.0625, 122.34375]]},
#   {'key': 'wdm',
#    'count': 96,
#    'bbox': [[12.65625, 119.53125], [14.0625, 120.9375]]},
#   {'key': 'wdp',
#    'count': 94,
#    'bbox': [[11.25, 122.34375], [12.65625, 123.75]]},
#   {'key': 'wdv',
#    'count': 72,
#    'bbox': [[15.46875, 119.53125], [16.875, 120.9375]]},
#   {'key': 'w9z', 'count': 72, 'bbox': [[9.84375, 122.34375], [11.25, 123.75]]},
#   {'key': 'wc1',
#    'count': 68,
#    'bbox': [[5.625, 125.15625], [7.03125, 126.5625]]},
#   {'key': 'wf2',
#    'count': 65,
#    'bbox': [[12.65625, 123.75], [14.0625, 125.15625]]},
#   {'key': 'wdt',
#    'count': 62,
#    'bbox': [[14.0625, 119.53125], [15.46875, 120.9375]]},
#   {'key': 'wc3',
#    'count': 60,
#    'bbox': [[7.03125, 125.15625], [8.4375, 126.5625]]},
#   {'key': 'weq',
#    'count': 59,
#    'bbox': [[18.28125, 120.9375], [19.6875, 122.34375]]},
#   {'key': 'wc2',
#    'count': 45,
#    'bbox': [[7.03125, 123.75], [8.4375, 125.15625]]},
#   {'key': 'w9n',
#    'count': 32,
#    'bbox': [[5.625, 120.9375], [7.03125, 122.34375]]},
#   {'key': 'wcb', 'count': 28, 'bbox': [[9.84375, 123.75], [11.25, 125.15625]]},
#   {'key': 'wc8',
#    'count': 25,
#    'bbox': [[8.4375, 123.75], [9.84375, 125.15625]]},
#   {'key': 'wdj',
#    'count': 24,
#    'bbox': [[11.25, 119.53125], [12.65625, 120.9375]]},
#   {'key': 'wem',
#    'count': 16,
#    'bbox': [[18.28125, 119.53125], [19.6875, 120.9375]]},
#   {'key': 'wej',
#    'count': 16,
#    'bbox': [[16.875, 119.53125], [18.28125, 120.9375]]},
#   {'key': 'wdn',
#    'count': 16,
#    'bbox': [[11.25, 120.9375], [12.65625, 122.34375]]},
#   {'key': 'wdx',
#    'count': 15,
#    'bbox': [[14.0625, 122.34375], [15.46875, 123.75]]},
#   {'key': 'wen',
#    'count': 14,
#    'bbox': [[16.875, 120.9375], [18.28125, 122.34375]]},
#   {'key': 'w9v',
#    'count': 14,
#    'bbox': [[9.84375, 119.53125], [11.25, 120.9375]]},
#   {'key': 'w9s',
#    'count': 14,
#    'bbox': [[8.4375, 118.125], [9.84375, 119.53125]]},
#   {'key': 'w9e',
#    'count': 12,
#    'bbox': [[8.4375, 116.71875], [9.84375, 118.125]]},
#   {'key': 'wc0', 'count': 11, 'bbox': [[5.625, 123.75], [7.03125, 125.15625]]},
#   {'key': 'wc6',
#    'count': 6,
#    'bbox': [[7.03125, 126.5625], [8.4375, 127.96875]]},
#   {'key': 'w9u', 'count': 5, 'bbox': [[9.84375, 118.125], [11.25, 119.53125]]},
#   {'key': 'w9q',
#    'count': 4,
#    'bbox': [[7.03125, 120.9375], [8.4375, 122.34375]]},
#   {'key': 'whd',
#    'count': 1,
#    'bbox': [[25.3125, 92.8125], [26.71875, 94.21875]]}],
#  'meta': {},
#  'links': {'self': 'https://api.orange.phl-microsat.xyz/scenes/geohash?geo_hash_precision=3'}}
